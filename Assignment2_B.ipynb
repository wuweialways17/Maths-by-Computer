# %%
import scipy.integrate as spi
import numpy as np
import pylab as pl
from math import sin,cos

miu = 1
INPUT = 0

def diff_eqs(INP,t):
    '''The main set of equations'''
    Y=0
    V = INP
    Y = cos(V)-miu*V
    return Y   # For odeint



def diff2_eqs(INP,t):
    Y=0
    V = diff_eqs(INP,t)
    Y = -sin(V)-miu*Y
    return Y   # For odeint


t_start = 0.0; t_end = math.pi ; t_inc = 0.01
t_range = np.arange(t_start, t_end+t_inc, t_inc)
RES = spi.odeint(diff2_eqs,INPUT,t_range)
 
#print (RES)
 
#Ploting
pl.subplot(111)
pl.plot(RES[:,0], '-g', label='Susceptibles')
pl.legend(loc=0)
pl.title('damped pendulum_Model.py')
pl.xlabel('time')
pl.ylabel('value')
pl.show()

# %%
import scipy.integrate as spi
import numpy as np
import pylab as pl
from math import sin,cos

miu = 0.1
INPUT = 1

def diff_eqs(INP,t):
    '''The main set of equations'''
    Y=0
    V = INP
    Y = cos(V)-miu*V
    return Y   # For odeint



def diff2_eqs(INP,t):
    Y=0
    V = diff_eqs(INP,t)
    Y = -sin(V)-miu*Y
    return Y   # For odeint


t_start = 0.0; t_end = math.pi ; t_inc = 0.01
t_range = np.arange(t_start, t_end+t_inc, t_inc)
RES = spi.odeint(diff2_eqs,INPUT,t_range)
 
#print (RES)
 
#Ploting
pl.subplot(111)
pl.plot(RES[:,0], '-g', label='Susceptibles')
pl.legend(loc=0)
pl.title('damped pendulum_Model.py')
pl.xlabel('time')
pl.ylabel('value')
pl.show()

# %%
import scipy.integrate as spi
import numpy as np
import pylab as pl
from math import sin,cos

miu = 0.1
INPUT = -1

def diff_eqs(INP,t):
    '''The main set of equations'''
    Y=0
    V = INP
    Y = cos(V)-miu*V
    return Y   # For odeint



def diff2_eqs(INP,t):
    Y=0
    V = diff_eqs(INP,t)
    Y = -sin(V)-miu*Y
    return Y   # For odeint


t_start = 0.0; t_end = math.pi ; t_inc = 0.01
t_range = np.arange(t_start, t_end+t_inc, t_inc)
RES = spi.odeint(diff2_eqs,INPUT,t_range)
 
#print (RES)
 
#Ploting
pl.subplot(111)
pl.plot(RES[:,0], '-g', label='Susceptibles')
pl.legend(loc=0)
pl.title('damped pendulum_Model.py')
pl.xlabel('time')
pl.ylabel('value')
pl.show()

# %%
from math import sin,cos
from plotdf import plotdf

def f(x,m=1):
    return np.array([cos(x[0])-m*x[0],-sin(x[0])-m*x[0]])

plotdf(f, # Function giving the rhs of the diff. eq. system
     np.array([-10,10]), # [xmin,xmax]
     np.array([-10,10]),# [ymin,ymax]
    
     # Additional parameters for `f` (optional)
     parameters={"m":0.3})
